# %% [markdown]
# # Imports

# %%
# !pip install gensim
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.21.6)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.2.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)

# %%
from gensim.models import Word2Vec

# %%
import numpy as np

# %%
import string
import sys
import io 
import nltk
import os

#remove stopwords
from gensim.parsing.preprocessing import remove_stopwords
from nltk.corpus import stopwords 
nltk.download('stopwords')
stops = set(stopwords.words('english'))
stopwords = nltk.corpus.stopwords.words('english')
#add to the stopwords list some archaic forms of pronouns that may be present in some translations
archaic = ['thou', 'thee', 'ye', 'thy', 'thine']
stopwords.extend(archaic)

#divide text in sentences based on points
nltk.download('punkt')

#tokenize strings in words
from nltk.tokenize import word_tokenize 

#lemmatization
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import wordnet
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()

#convert position tag in a form suitable for the lemmatizer
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

#count unique words
from collections import Counter

#explore results
import random
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Introduction
# We compare the corpora obtained with and without lemmatization for each religion. We focus on the number of total and unique words obtained, we print some random sentences and we look at the 10 most frequent words.
#
# Additionaly we perform an indicative analysis of the stability of the models trained on the lemmatized and non lemmatized corpora:
#
# 1) we create a list x of 5 manually selected words;
#
# 2) for each religion, we train 5 word2vec models on the lemmatized corpora;
#
# 3) for each model, we obtain the 5 most similar words to each of the words in the list x and we add them to a list y;
#
# 4) we count the number of unique words in list y;
#
# 5) we perform the same operations from point 2 but with non lemmatized corpora.
#
# For each religion, we compare the values of unique words obtained for lemmatized and non lemmatized corpora. These values are general indicators of the stability of the models because they describe how many words change from one iteration to another in the list of 5 most similar to a given one. Ideally they should be equal to 25, the 5 most similar words to the 5 given ones don't change across the 5 models.

# %% [markdown]
# # Functions

# %%
def getsentences(file_name):
  sentences = []

  with open(file_name + '_nl.txt', 'r') as fp:
      for line in fp:
          x = line[1:-2]
          x = x.replace('\'','')
          x = x.replace(' ', '')
          x = x.split(',')

          sentences.append(x)
          
  return sentences

# %%
def checkresults(sentences):
  #explore the results
  words = []
  for i in range(len(sentences)):
    for j in range(len(sentences[i])):
      words.append(sentences[i][j])

  #number of words
  print('N.words: ' + str(len(words)))

  #number of unique words
  word_count = Counter(words)
  keys = word_count.keys()
  print('N.unique words: '+ str(len(keys)))

  fract = round(len(words) / len(keys), 2)
  print('N.words / N.unique words: ' + str(fract))

  #most common words
  print('Most common words:')
  print(word_count.most_common(10))

  #print some sentences
  print('Random sentences:')
  randomlist = random.sample(range(0, len(sentences)), 25)
  for i in randomlist:
    print(sentences[i])

# %%
def compare_lem(filename):
  print('***WITH LEMMATIZATION***')
  os.chdir('/content/drive/MyDrive/Magistrale/Secondo semestre/DS/Progetto/Sentences_W2V')
  sentences = getsentences(filename)
  checkresults(sentences)

  print('***WITHOUT LEMMATIZATION***')
  os.chdir('/content/drive/MyDrive/Magistrale/Secondo semestre/DS/Progetto/Sentences_nl')
  sentences_nl = getsentences(filename + '_nl')
  checkresults(sentences_nl)

# %%
def get5words(sentences):
  random_words = ['woman', 'god', 'violence', 'fire', 'death']#hell for christ and isl
  words = []
  for i in range(5):
    model = Word2Vec(sentences = sentences,
                    min_count=10, #not consider word with absolute frequency <10 
                    size=300, #vector size 
                    sg = 1, #skipgram algorithm
                    hs = 0,
                    negative = 5, #negative sampling with 5 noise words
                    workers = 5, #faster process
                    iter = 6 #6 iterations
                    )
    for word in random_words:
      for tupl in model.wv.most_similar(word)[:5]:
        words.append(tupl[0])
    
  return len(np.unique(words))

# %%
def compare_stability(filename):
  os.chdir('/content/drive/MyDrive/Magistrale/Secondo semestre/DS/Progetto/Sentences_W2V')
  sentences = getsentences(filename)
  print('***WITH LEMMATIZATION***, n.unique words:', get5words(sentences))  
  
  os.chdir('/content/drive/MyDrive/Magistrale/Secondo semestre/DS/Progetto/Sentences_nl')
  sentences_nl = getsentences(filename + '_nl')
  print('***WITHOUT LEMMATIZATION***, n.unique words:', get5words(sentences_nl))

# %% [markdown]
# # Comparison

# %% [markdown]
# ## Bible

# %%
compare_lem('Christian_sentences')
# Out:
# ***WITH LEMMATIZATION***
# N.words: 998432
# N.unique words: 14544
# N.words / N.unique words: 68.65
# Most common words:
# [('say', 18547), ('shall', 17608), ('lord', 17167), ('god', 13274), ('come', 11181), ('son', 10162), ('go', 9781), ('unto', 8972), ('king', 8540), ('man', 7237)]
# Random sentences:
# ['jehoshaphat', 'also', 'say', 'king', 'israel', 'first', 'seek', 'counsel', 'lord']
# ['egyptian', 'mourn', 'seventy', 'day']
# ['believe']
# ['thus', 'paul', 'go', 'among']
# ['binding', 'foal', 'vine', 'donkey', 'colt', 'choice', 'vine', 'wash', 'garment', 'wine', 'robe', 'blood', 'grape']
# ['priest', 'answer', 'unclean']
# ['zebah', 'zalmunna', 'karkor', 'host', 'fifteen', 'thousand', 'men', 'left', 'host', 'child', 'east', 'fell', 'hundred', 'twenty', 'thousand', 'men', 'drew', 'sword']
# ['son', 'merari', 'give', 'lot', 'accord', 'family', 'tribe', 'reuben', 'tribe', 'gad', 'tribe', 'zebulun', 'twelve', 'city']
# ['lord', 'hand', 'lift', 'see', 'shall', 'see', 'ashamed', 'envy', 'people', 'yea', 'fire', 'enemy', 'shall', 'devour']
# ['god', 'praise', 'word']
# ['balm', 'gilead']
# ['ask', 'shall', 'give', 'seek', 'shall', 'find', 'knock', 'shall', 'open', 'unto', 'every', 'one', 'asketh', 'receiveth', 'seeketh', 'findeth', 'knocketh', 'shall', 'open']
# ['good']
# ['shall', 'wander', 'food', 'wait', 'night', 'satisfied']
# ['thing', 'count', 'faith', 'express', 'love']
# ['covert', 'sabbath', 'built', 'house', 'king', 'entry', 'without', 'turn', 'house', 'lord', 'king', 'assyria']
# ['ox', 'wont', 'push', 'horn', 'time', 'past', 'hath', 'testify', 'owner', 'hath', 'kept', 'hath', 'kill', 'man', 'woman', 'ox', 'shall', 'stone', 'owner', 'also', 'shall', 'put', 'death']
# ['micaiah', 'say', 'lord', 'liveth', 'even', 'god', 'saith', 'speak']
# ['god', 'abner', 'also', 'yahweh', 'sworn', 'david', 'even', 'transfer', 'kingdom', 'house', 'saul', 'set', 'throne', 'david', 'israel', 'judah', 'dan', 'even', 'beersheba']
# ['meanwhile', 'joab', 'fought', 'rabbah', 'ammonite', 'capture', 'royal', 'citadel']
# ['build', 'house', 'name', 'shed', 'much', 'blood', 'earth', 'sight']
# ['shall', 'take', 'stone', 'corner', 'stone', 'foundation', 'shalt', 'desolate', 'ever', 'saith', 'lord']
# ['heaven', 'high', 'earth', 'great', 'mercy', 'toward', 'fear']
# ['passover', 'jew', 'hand']
# ['one', 'pharisee', 'invite', 'eat']
# ***WITHOUT LEMMATIZATION***
# N.words: 1004875
# N.unique words: 19157
# N.words / N.unique words: 52.45
# Most common words:
# [('shall', 17608), ('lord', 17074), ('god', 12527), ('said', 11024), ('unto', 8972), ('king', 7537), ('man', 7235), ('son', 7098), ('israel', 7009), ('yahweh', 6807)]
# Random sentences:
# ['make', 'curtains', 'goat', 'hair', 'tent', 'altogether']
# ['eyes', 'ways']
# ['joseph', 'made', 'ready', 'chariot', 'went', 'meet', 'israel', 'father', 'goshen']
# ['behold', 'glory', 'god', 'israel', 'came', 'way', 'east', 'voice', 'like', 'sound', 'many', 'waters', 'earth', 'shined', 'glory']
# ['redeemed', 'means', 'shall', 'released', 'year', 'jubilee', 'children']
# ['woman', 'said', 'devised', 'thing', 'people', 'god']
# ['dwelt', 'havilah', 'unto', 'shur', 'egypt', 'goest', 'toward', 'assyria', 'died', 'presence', 'brethren']
# ['entered', 'boat', 'crossed', 'came', 'city']
# ['dove', 'art', 'clefts', 'rock', 'secret', 'places', 'stairs', 'let', 'see', 'countenance', 'let', 'hear', 'voice', 'sweet', 'voice', 'countenance', 'comely']
# ['followed', 'practices', 'israel', 'introduced']
# ['sin', 'mouth', 'words', 'lips', 'let', 'caught', 'pride', 'curses', 'lies', 'utter']
# ['five', 'kings', 'kings', 'jerusalem', 'hebron', 'jarmuth', 'lachish', 'forces']
# ['house', 'build', 'great', 'great', 'god', 'gods']
# ['powers', 'work']
# ['dull']
# ['denied', 'oath', 'know', 'man']
# ['remember', 'journey', 'shittim', 'gilgal', 'may', 'know', 'righteous', 'acts', 'lord']
# ['happened', 'jacob', 'saw', 'rachel', 'daughter', 'laban', 'mother', 'brother', 'sheep', 'laban', 'mother', 'brother', 'jacob', 'went', 'near', 'rolled', 'stone', 'well', 'mouth', 'watered', 'flock', 'laban', 'mother', 'brother']
# ['jesse', 'said', 'unto', 'david', 'son', 'take', 'brethren', 'ephah', 'parched', 'corn', 'ten', 'loaves', 'run', 'camp', 'brethren', 'carry', 'ten', 'cheeses', 'unto', 'captain', 'thousand', 'look', 'brethren', 'fare', 'take', 'pledge']
# ['profit', 'circumcision']
# ['called', 'name', 'place', 'massah', 'meribah', 'chiding', 'children', 'israel', 'tempted', 'lord', 'saying', 'lord', 'among', 'us']
# ['sabbath', 'dawn', 'first', 'day', 'week', 'mary', 'magdalene', 'mary', 'went', 'look', 'tomb']
# ['doeg', 'edomite', 'standing', 'saul', 'officials', 'said', 'saw', 'son', 'jesse', 'come', 'ahimelech', 'son', 'ahitub', 'nob']
# ['answered', 'doeg', 'edomite', 'set', 'servants', 'saul', 'said', 'saw', 'son', 'jesse', 'coming', 'nob', 'ahimelech', 'son', 'ahitub']
# ['fall', 'riches', 'world', 'diminishing', 'riches', 'gentiles', 'much', 'fulness']

# %%
compare_stability('Christian_sentences')
# Out:
# ***WITH LEMMATIZATION***
# ***WITH LEMMATIZATION***, n.unique words: 45
# ***WITHOUT LEMMATIZATION***
# ***WITHOUT LEMMATIZATION***, n.unique words: 45

# %% [markdown]
# ## Quran

# %%
compare_lem('Islam_sentences')
# Out:
# ***WITH LEMMATIZATION***
# N.words: 784801
# N.unique words: 16763
# N.words / N.unique words: 46.82
# Most common words:
# [('allah', 18177), ('say', 14317), ('god', 11049), ('lord', 8197), ('people', 6437), ('one', 5865), ('give', 5610), ('make', 5609), ('day', 5174), ('come', 5068)]
# Random sentences:
# ['thing', 'overflow', 'right', 'throat', 'choke']
# ['chosen', 'impose', 'difficulty', 'religion', 'cult', 'father', 'abraham']
# ['mankind']
# ['betray', 'allah', 'messenger', 'betray', 'knowingly', 'amdndt', 'thing', 'entrust', 'duty', 'allah', 'ordain']
# ['detailed', 'verse', 'people', 'remember']
# ['invisible', 'heaven', 'earth']
# ['whereof', 'use', 'doubt']
# ['allah', 'say', 'strengthen', 'arm', 'brother', 'give', 'power', 'shall', 'able', 'harm', 'aydt', 'proof', 'evidence', 'verse', 'lesson', 'sign', 'revelation', 'etc']
# ['low', 'raise', 'high']
# ['chosen', 'deity', 'earth']
# ['point']
# ['circular', 'motion', 'earthquake']
# ['god']
# ['preordainments', 'everything', 'bless', 'wretched', 'show', 'mankind', 'right', 'wrong', 'path', 'guide', 'pasture']
# ['god', 'make', 'covenant', 'prophet', 'say', 'give', 'book', 'wisdom', 'messenger', 'come', 'testify', 'guidance', 'receive', 'must', 'believe', 'help', 'ask', 'affirm', 'accept', 'covenant']
# ['dawood']
# ['narrate', 'sahl', 'bin', 'sa', 'ii', 'prophet', 'rl', 'ii', 'say', 'person', 'look', 'orphan', 'provide', 'paradise', 'like', 'put', 'index', 'middle', 'finger', 'together']
# ['magician', 'certainly', 'happiness']
# ['believe']
# ['seek', 'honor']
# ['appeal', 'make', 'israel', 'subjectively', 'term', 'tradition']
# ['far', 'evidence', 'existence', 'ship', 'stand', 'mountain', 'sea']
# ['allah', 'create', 'dust', 'make', 'pair', 'female', 'bear', 'bring', 'forth', 'except', 'knowledge', 'one', 'whose', 'life', 'lengthen', 'life', 'lengthen', 'aught', 'diminish', 'one', 'life', 'book', 'surely', 'easy', 'allah']
# ['whoever', 'disbelief', 'believe', 'allœh', 'grasped', 'trustworthy', 'handhold', 'break']
# ['give', 'good', 'child', 'ascribe', 'partner', 'concern', 'give']
# ***WITHOUT LEMMATIZATION***
# N.words: 791238
# N.unique words: 22069
# N.words / N.unique words: 35.85
# Most common words:
# [('allah', 18177), ('god', 10529), ('lord', 8142), ('said', 6920), ('people', 6299), ('say', 6188), ('one', 5049), ('day', 4746), ('shall', 4524), ('us', 4502)]
# Random sentences:
# ['us']
# ['allah']
# ['givest', 'kingdom', 'whomsoever', 'pleasest', 'takest', 'away', 'kingdom', 'whomsoever', 'pleasest', 'exaltest', 'pleasest', 'abasest', 'pleasest', 'hand', 'good', 'surety', 'hast', 'power', 'things']
# ['falsehood', 'go', 'wrong', 'message', 'described', 'last', 'note', 'anyone', 'ignore', 'treat', 'contempt', 'refuse', 'allow', 'improve', 'life']
# ['sense']
# ['hypocrites']
# ['blind', 'man', 'became', 'true', 'sincere', 'muslim', 'lived', 'become', 'governor', 'madinah']
# ['ingrates']
# ['parable', 'bad', 'word', 'bad', 'uprooted', 'ground', 'stability']
# ['believers']
# ['pharaoh', 'said', 'produce', 'truthful']
# ['morn', 'breathes']
# ['allah', 'unaware']
# ['combination', 'includes', 'three', 'letters', 'alif', 'lam', 'mim', 'occurred', 'beginning', 'surah', 'discussed']
# ['believe']
# ['creator', 'designer', 'modeler', 'belong', 'virtuous', 'names']
# ['favours', 'lord', 'deny', 'come', 'terrors', 'judgement', 'evil', 'ones']
# ['used', 'enter', 'vain', 'discourse', 'entered', 'vain', 'discourses']
# ['warner', 'fear', 'day']
# ['allah', 'comprehends']
# ['simple', 'superstition', 'houses', 'possession', 'actual', 'occupation', 'disapproved']
# ['people']
# ['day', 'earth', 'changed', 'earth', 'heavens', 'also', 'changed', 'come', 'forth', 'god', 'one', 'almighty']
# ['god', 'willed', 'choose', 'son', 'could', 'chosen', 'would', 'created']
# ['everyone', 'direction', 'vie', 'one', 'another', 'good', 'works']

# %%
compare_stability('Islam_sentences')
# Out:
# ***WITH LEMMATIZATION***, n.unique words: 41
# ***WITHOUT LEMMATIZATION***, n.unique words: 46

# %% [markdown]
# ## Hinduism

# %%
compare_lem('Hinduism_sentences')
# Out:
# ***WITH LEMMATIZATION***
# N.words: 687793
# N.unique words: 15229
# N.words / N.unique words: 45.16
# Most common words:
# [('indra', 9161), ('god', 8586), ('agni', 7747), ('may', 7321), ('one', 5446), ('sacrifice', 5307), ('come', 5256), ('soma', 5184), ('verily', 5121), ('make', 4214)]
# Random sentences:
# ['pas', 'asvins', 'pas', 'away', 'beyond', 'tribe', 'selfish', 'men', 'wonderful', 'golden', 'path', 'gracious', 'bringers', 'flood']
# ['sing', 'glory', 'indra', 'say', 'solemn', 'eulogy']
# ['may', 'flow', 'give', 'wealth', 'thousand', 'heroic', 'power', 'godlike', 'soma', 'drop', 'effuse']
# ['flow', 'way', 'active']
# ['among', 'skilful', 'god', 'skilled', 'make', 'two', 'bring', 'prosperity', 'great', 'wisdom', 'measure', 'region', 'stablished', 'pillar', 'shall', 'decay']
# ['maintain', 'growth', 'wealth', 'men', 'sacrifice']
# ['language', 'express', 'must', 'finite', 'since', 'finite']
# ['three', 'veda']
# ['may', 'earn', 'glory', 'good', 'action']
# ['art', 'dear', 'friend', 'mighty', 'morning', 'shinest', 'glimmering', 'night']
# ['thence', 'sprang', 'world', 'uprose', 'region', 'thence', 'heaven', 'spread', 'wide', 'earth', 'expan', 'ded']
# ['takman', 'become', 'eager', 'go', 'balhikas']
# ['god', 'declares', 'deity', 'generation', 'like', 'usana', 'proclaim', 'lofty', 'wisdom']
# ['hymn', 'clxxvi']
# ['mantra', 'cake', 'agni', 'prajapati', 'assign', 'sacrifice', 'god']
# ['god']
# ['thrice', 'gavest', 'sunlike', 'skin', 'drawn', 'satakratu']
# ['greatness', 'king', 'firmly', 'stablished', 'earth', 'heaven', 'cause', 'cow', 'stream', 'plant', 'flourish', 'scatter', 'swift', 'drop', 'sent']
# ['may', 'wing', 'courser', 'best', 'draw']
# ['nostril', 'eye', 'ear', 'chin', 'forth', 'head', 'brain', 'tongue', 'drive', 'malady', 'away']
# ['born', 'whatever', 'appear', 'brought', 'hither', 'sage', 'rohita']
# ['charm', 'far', 'away', 'unto', 'distant', 'region', 'people', 'shall', 'behold']
# ['give', 'life', 'unwasting', 'jatavedas', 'employ', 'never', 'shalt', 'injured']
# ['agni', 'turn', 'wealth', 'sprinkle', 'everyside']
# ['atri', 'bharadvaja', 'gavisthira', 'kanva', 'trasadasyu', 'fight', 'help']
# ***WITHOUT LEMMATIZATION***
# N.words: 697742
# N.unique words: 18874
# N.words / N.unique words: 36.97
# Most common words:
# [('us', 9479), ('indra', 9161), ('agni', 7731), ('may', 7321), ('gods', 6141), ('verily', 5121), ('soma', 5080), ('one', 4683), ('sacrifice', 4405), ('come', 4361)]
# Random sentences:
# ['made', 'pure', 'prayer', 'flow', 'indu', 'flow', 'indra', 'sake']
# ['let', 'surround', 'tristubh', 'tristubh', 'power', 'rajanya', 'sacrifices', 'desire', 'power', 'verily', 'tristubh', 'secures', 'power']
# ['essence', 'earthly', 'bliss', 'gods', 'strength', 'body', 'may', 'live']
# ['praises', 'come', 'meet', 'us', 'bright', 'sunlight', 'agni', 'well', 'disposed', 'aspects']
# ['noble', 'gladdening', 'friendly', 'one']
# ['defer', 'maghavan', 'longing', 'art', 'director', 'indra', 'art', 'giver']
# ['right', 'worker', 'leaders', 'host', 'bands', 'rathasvana', 'rathecitra', 'menaka', 'sahajanya', 'apsarases', 'missile', 'biting', 'beasts', 'weapon', 'death', 'men']
# ['iv']
# ['hero', 'deserves', 'laud', 'none', 'aid', 'tribes', 'men']
# ['awakened', 'songs', 'praise', 'asvins', 'kindred', 'prayers', 'celestial', 'mornings']
# ['dawn']
# ['soma', 'flowest', 'chasing', 'foes', 'bringing', 'wisdom', 'delight', 'drive', 'folk', 'love', 'gods']
# ['svaha']
# ['truth', 'rests', 'strength']
# ['turbid', 'darkness', 'fled', 'heaven', 'sp', 'endid']
# ['chariot', 'majesties', 'fourteen', 'others', 'seven', 'sages', 'lead', 'onward', 'voices']
# ['god', 'shine', 'forth', 'night', 'morn', 'fires', 'provided', 'well']
# ['reachable', 'worship', 'path', 'truth', 'virtue']
# ['didst', 'break', 'forth', 'asvattha', 'great', 'flood', 'air', 'thus', 'break', 'hate', 'hate']
# ['prosperity', 'us', 'sky', 'agni', 'earth', 'full', 'life', 'procure', 'god', 'worship', 'splendid', 'thing', 'ask', 'bestow', 'upon', 'us', 'radiant', 'wealth']
# ['piles', 'fire', 'falls', 'away', 'world', 'libation', 'performed', 'place', 'without', 'bricks', 'whatever', 'libation', 'offers', 'place', 'without', 'bricks', 'runs', 'away', 'running', 'away', 'sacrifice', 'ruined', 'sacrifice', 'sacrificer', 'piles', 'second', 'piling', 'support', 'libations', 'libations', 'find', 'support', 'sacrifice', 'ruined', 'yajur', 'veda', 'english', 'translation', 'ab', 'keith', 'sacrificer']
# ['strength', 'limb', 'hero', 'slays', 'hero', 'bright', 'arms', 'range', 'combat']
# ['prince', 'seek', 'devour', 'cow', 'brâhmana', 'unfit', 'eaten']
# ['glorify']
# ['ii']

# %%
compare_stability('Hinduism_sentences')
# Out:
# ***WITH LEMMATIZATION***, n.unique words: 48
# ***WITHOUT LEMMATIZATION***, n.unique words: 44

# %% [markdown]
# ## Buddhism

# %%
compare_lem('Buddhism_sentences')
# Out:
# ***WITH LEMMATIZATION***
# N.words: 403186
# N.unique words: 15349
# N.words / N.unique words: 26.27
# Most common words:
# [('one', 5409), ('buddha', 3496), ('see', 3066), ('say', 2604), ('people', 2217), ('also', 1930), ('time', 1747), ('way', 1673), ('life', 1662), ('world', 1658)]
# Random sentences:
# ['dharma', 'teacher', 'hui', 'yuan', 'response', 'great', 'way', 'profound', 'principle', 'abstruse']
# ['hearing', 'exhortation', 'people', 'world', 'decide', 'attain', 'fourth', 'meditative', 'state', 'absorption', 'body', 'dissolve', 'life', 'come', 'end', 'born', 'bṛhatphala', 'heaven']
# ['also', 'refer', 'text', 'rocana']
# ['forty', 'chapter', 'briefly', 'discuss', 'important', 'point']
# ['person', 'great', 'bright', 'wisdom', 'gradually', 'advance', 'discriminate', 'cognition', 'illuminates', 'immeasurably', 'immeasurably']
# ['reverence', 'also', 'well', 'train', 'reading', 'physiognomy', 'magnanimous', 'personality', 'divine', 'good', 'bad', 'omen', 'conduct', 'ceremonial', 'proceeding', 'sacriﬁcial', 'rite']
# ['ch']
# ['thus', 'list', 'label', 'name', 'ten', 'precept', 'traditionally', 'adopt', 'one', 'major', 'commentary', 'sutra']
# ['pārājika']
# ['chang', 'ahan', 'jing', '長阿含經', 'skt']
# ['joyful', 'make', 'worship', 'ﬁtting']
# ['throughout', 'whole', 'life', 'experience', 'last', 'suffer', 'never', 'obtains', 'happiness']
# ['land', 'jambudvīpa']
# ['nine', 'hundred', 'śākyas', 'manifest', 'ten', 'trillion', 'śākyas', 'way']
# ['think', 'every', 'place', 'unique', 'custom']
# ['second', 'kind', 'causal', 'factor']
# ['see', 'disciple', 'path', 'srotaāpanna']
# ['later', 'people', 'give', 'rise', 'love', 'praise', 'ruler', 'decorum', 'developed']
# ['rely', 'duke', 'zhou', 'confucius', 'educate', 'mass', 'taste', 'buddhist', 'dharma', 'nourish', 'spirit', 'intelligent', 'ruler', 'lifetime', 'bright', 'spirit', 'death', 'always', 'manage', 'myriad', 'cycle', 'existence']
# ['sutra', 'last', 'journey', 'sojourn', 'time', 'one', 'maintain', 'silence', 'thus', 'grant', 'wish']
# ['manner', 'theory', 'previously', 'advanced', 'fall', 'four', 'variation', 'exceed', 'number']
# ['answer', 'king', 'linchuan', 'receive', 'imperial', 'response', 'subject', 'examination', 'discourse', 'extinction', 'spirit', 'sent']
# ['well', 'train', 'serve', 'mount', 'immediately', 'set', 'see', 'elephant', 'could', 'train', 'found', 'capable', 'training']
# ['look', 'upon', 'life', 'one', 'see', 'dungeon', 'go', 'astray']
# ['could', 'intentionally', 'use', 'inexplicit', 'language', 'try', 'explain', 'away', 'absurdity']
# ***WITHOUT LEMMATIZATION***
# N.words: 404717
# N.unique words: 19699
# N.words / N.unique words: 20.55
# Most common words:
# [('one', 5275), ('buddha', 3319), ('see', 2622), ('people', 2216), ('also', 1930), ('world', 1570), ('great', 1547), ('way', 1506), ('three', 1473), ('life', 1470)]
# Random sentences:
# ['chaos', 'universe', 'took', 'shape', 'compared', 'egg', 'undeveloped', 'state', 'ignorance', 'likened', 'innocent', 'condition', 'infant']
# ['ten', 'wholesome', 'acts', 'four', 'immeasurable', 'minds', 'considered', 'acts', 'lead', 'us', 'reborn', 'heaven']
# ['honoring', 'bowing', 'foreheads', 'feet', 'withdrew', 'one', 'side', 'take', 'seats']
# ['temporary', 'nature', 'life', 'like', 'perceive', 'truth', 'intelligence', 'insight', 'freely', 'wield', 'sword', 'wisdom']
# ['reward']
# ['naxian', 'biqiu', 'jing', '那先比丘經', 'pāli', 'milindapañhā', 'ch']
# ['go', 'see', 'man', 'together', 'thereupon', 'villagers', 'brāhmaṇas', 'wealthy', 'householders', 'alike', 'immediately', 'departed', 'together', 'resulting', 'great', 'exodus']
# ['close', 'relation', 'maintained', 'ten', 'kinds', 'good', 'deeds']
# ['someone', 'might', 'say', 'king', 'kṣatriya', 'class', 'may', 'wish', 'conduct', 'great', 'sacriﬁcial', 'rite', 'countenance', 'unattractive', 'since', 'kṣatriya', 'even', 'rumor', 'disgrace', 'king']
# ['could', 'expect', 'fundamental', 'principle', 'words', 'sage', 'buddha', 'discourse', 'states', 'either', 'nirvana', 'transformation', 'becoming', 'transcendent', 'method', 'unite', 'way']
# ['asceticism', 'seek', 'happiness', 'rebirth', 'heaven']
# ['since', 'even', 'wise', 'people', 'middle', 'class', 'cut', 'deﬁlement', 'maintain', 'life', 'would', 'people', 'ordinary', 'intelligence', 'able', 'accomplish', 'discourse', 'three', 'periods', 'reward', 'retribution', 'sanbaolun', 'composed', 'doubt', 'testimony', 'reward', 'retribution', 'corresponding', 'good', 'bad', 'conduct', 'dharma', 'teacher', 'hui', 'yuan', 'stated', 'buddhist', 'scripture', 'three', 'different', 'periods', 'good', 'evil', 'actions', 'mature', 'bring', 'effects', 'reward', 'retribution', 'ﬁrst', 'reward', 'retribution', 'present', 'existence', 'second', 'next', 'existence', 'last', 'existence', 'next']
# ['sink', 'retreat', 'fall', 'linger']
# ['discipline', 'austerity', 'based', 'superior', 'type', 'ascetic', 'practice']
# ['exert', 'inquiring', 'populace', 'assisting', 'security', 'possessions']
# ['wisdom', 'shines', 'darkness', 'soon', 'become', 'dark']
# ['everyone', 'learn', 'mind', 'determination', 'skt']
# ['must', 'know', 'everything', 'impermanent', 'bound', 'decay', 'destruction', 'hence', 'nothing', 'one', 'hold', 'rely']
# ['nuns', 'wear', 'robes', 'anner', 'monks', 'respective', 'schools', 'ith', 'difference']
# ['people', 'neglect', 'profound', 'superb', 'yet', 'covet', 'familiar']
# ['mañjuśrīparipṛcchā', 'eng']
# ['different', 'local', 'conditions', 'variant', 'physical', 'constitutions']
# ['moreover', 'aware', 'say', 'even', 'though', 'people', 'born', 'equally', 'placed', 'great', 'virtue', 'called', 'sentient', 'beings']
# ['hongdao', 'yu', 'mingjiao', 'hongmingji', 'yanjiu']
# ['vīrya', 'meditation', 'skt']

# %%
compare_stability('Buddhism_sentences')
# Out:
# ***WITH LEMMATIZATION***, n.unique words: 39
# ***WITHOUT LEMMATIZATION***, n.unique words: 44

# %% [markdown]
# # Conclusion
# We have higher values of total words for non lemmatized corpora, this could be  due to non lemmatized forms of stop words that have not been eliminated.
# As expected we also have higher values of unique words for the non lemmatized corpora since two non lemmatized forms of the same lemma are considered as different words. We have lower values of the ratio total words/unique words for the non lemmatized corpora.
#
# Lemmatization increases the frequency of some common used verbs like come or say, because all the forms of the verb are brought to the basic form. By removing lemmatization some more interesting words for our analysis than this verbs appear among the top 10 most common words. As an example in the bible corpora we can see that without lemmatization 'israel' and 'yahweh' are among the 10 most common words in substitution of two verbs like 'come' and 'go'. A higher frequency percentile increase the reliability of a word(Hellrich&Hann, 2016) and we are more interested in increasing the reliabilty of words like 'yahweh' than common verbs.
#
# Regarding the stability analysis, for the Bible the number of unique words is the same for lemmatized and non lemmatized corpora, for the Quran we have 6 more unique words with the non lemmatized corproa, for the Vedas and Upanishads we have 4 more unique words for the lemmatized corpora, for the Tripitaka we have 5 more unique words for the non lemmatized corpora. We can't say that one choice clearly outperform the other.
#
# Given this considerations, we decide to use the non lemmatized corpora for our analysis.
